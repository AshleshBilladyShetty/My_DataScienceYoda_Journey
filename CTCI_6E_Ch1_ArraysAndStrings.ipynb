# %% [markdown]
# Binder Documentation: https://github.com/alan-turing-institute/the-turing-way/blob/master/workshops/boost-research-reproducibility-binder/workshop-presentations/zero-to-binder-python.md

# %% [markdown]
# ## TOC: <a id=0-b ></a>
# * [(1) Hash Tables](#1-b)
# * [(2)  ArrayList & resizable arrays](#2-b)
# * [(3) String builder](#3-b)
# * [(4)  Interview question difficulty mapping](#4-b)

# %% [markdown]
# # (1) Hash Tables <a id=1-b ></a>
# [TOC](#0-b)

# %% [markdown]
# **(1)**  Hast tables python implementation:
# http://blog.chapagain.com.np/hash-table-implementation-in-python-data-structures-algorithms/
# **Refer above link understand and try to implement without seeing below**
#
# **(2)**  Link to class object basic in python: https://www.geeksforgeeks.org/python-classes-and-objects/
#
# **(3)** Markdown links https://www.markdownguide.org/basic-syntax/
#
# **(4)** Good python hashtable explaination https://www.guru99.com/design-analysis-algorithms-tutorial.html
#
# **(5)** How python dictionary are implemented rough idea: Python uses hashtable to implement dictionary. and hash function varies based on the dataype of the key. Pyhtpn uses open addressing for managing hash collision.  https://stackoverflow.com/questions/8997894/what-hash-algorithm-does-pythons-dictionary-mapping-use
#
# **(6)** Beautiful article to understand how collision is handeled in Hash table: Open addressing vs chaining: https://www.geeksforgeeks.org/hashing-set-3-open-addressing/
#
# **(7)** Article which clearly says that dictionary is not equal to hashtables. Hashtable is one way of impementing dictionaries. Python uses hash table implementation to implement dictionaries. Dictionaries can also be implemented using "red-black treees" https://medium.com/@erikbatista42/an-introduction-to-hash-tables-with-python-817772cad688

# %% [markdown]
# ## OOP basics in python

# %%
class Dog:
   
    # Class Variable
    animal = 'dog'            
   
    # The init method or constructor
    def __init__(self, breed, color):
     
        # Instance Variable    
        self.breed = breed
        self.color = color
    
    def set_owner(self, ownername):
        self.ownername = ownername

    def get_owner(self):
        return self.ownername
        
# Objects of Dog class
Rodger = Dog("Pug", "brown")
 
print('Rodger details:')  
print('Rodger is a', Rodger.animal)
print('Breed: ', Rodger.breed)
print('Color: ', Rodger.color)
  
# Class variables can be accessed using class name also
print("\nAccessing class variable using class name")
print(Dog.animal) 

# call function inside class
Rodger.set_owner('Antony')
print( 'ownername way 1: ',Rodger.ownername)
print( 'ownername way 2: ',Rodger.get_owner())
# Out:
# Rodger details:
# Rodger is a dog
# Breed:  Pug
# Color:  brown
#
# Accessing class variable using class name
# dog
# ownername way 1:  Antony
# ownername way 2:  Antony

# %% [markdown]
# ## Hashtable implementation in Python

# %%
class HashTable:
    
    def __init__(self):
        self.hash_table = [ [] for i in range(10)]
    
    def hash_func(self, key):
        hash_key = key % len(self.hash_table)
        return hash_key
    
    def insert(self, key, value):        
        hash_key = self.hash_func(key)
        key_present = False
        bucket = ht1.hash_table[hash_key]
        for i, kv in enumerate(bucket):
            k, v = kv
            if k == key:
                key_present = True
                break
        
        if key_present:
            bucket[i] = (key, value)
        else:
            bucket.append((key,value))
            
        return self.hash_table            

    def search(self, key):
        hash_key = self.hash_func(key)
        key_present = False
        bucket = ht1.hash_table[hash_key]
        for i, kv in enumerate(bucket):
            k, v = kv
            if k == key:
                key_present = True
                break

        if key_present:
            value = bucket[i]
        else:
            value = print('Key not present in the hash table.')
            
        return value

    def delete(self, key):
        hash_key = self.hash_func(key)
        key_present = False
        bucket = ht1.hash_table[hash_key]
        for i, kv in enumerate(bucket):
            k, v = kv
            if k == key:
                key_present = True
                break

        if key_present:
            del bucket[i]
            
        return self.hash_table

# %%
ht1 = HashTable()
ht1.insert(20, 'Nepal')
ht1.insert(35, 'USA')
ht1.insert(30, 'Srilanka')
ht1.insert(30, 'Asia')
ht1.insert(20, 'EU')
# Out:
# [[(20, 'EU'), (30, 'Asia')], [], [], [], [], [(35, 'USA')], [], [], [], []]

# %%
ht1.search(35)
# Out:
# (35, 'USA')

# %%
ht1.search(45)
# Out:
# Key not present in the hash table.

# %%
ht1.delete(20)
# Out:
# [[(30, 'Asia')], [], [], [], [], [(35, 'USA')], [], [], [], []]

# %% [markdown]
# # (2)  ArrayList & resizable arrays <a id=2-b ></a>
# [TOC](#0-b)

# %% [markdown]
# **(1)**  Difference between Python Language, Python implementations and Python executable https://www.reddit.com/r/learnpython/comments/8m10q1/python_vs_ipython/
#
# **(2)** Python implementations comparisons https://www.toptal.com/python/why-are-there-so-many-pythons, https://www.geeksforgeeks.org/difference-various-implementations-python/
#
# **(3)** Resizing factor for lists (dynamic aray or arraylist or resizable list) in Python under CPython implementation *1.125 * new_size + 6 (or + 3 when the array is smaller than 9 elements)* https://www.quora.com/How-are-Python-lists-implemented-internally
#
# **(4)** In python Lists are nothing but dynamic array: Sample implementation https://www.geeksforgeeks.org/implementation-of-dynamic-array-in-python/

# %% [markdown]
# # (3)  String Builder <a id=3-b ></a>
# [TOC](#0-b)

# %% [markdown]
# **(1)** String builder equivalent in python https://www.delftstack.com/howto/python/stringbuilder-in-python/

# %% [markdown]
# # (4)  Interview question difficulty mapping <a id=4-b ></a>
# [TOC](#0-b)

# %% [markdown]
# **(1)** Ranjita leetcode link https://leetcode.com/ranjitarajeeva/
# **(2)** CTCI to leetcode problems mapping to identify easy problems and solve https://leetcode.com/discuss/general-discussion/1152824/cracking-the-coding-interview-6th-edition-in-leetcode

# %% [markdown]
# Chapter 1: Arrays and Strings
# 1.1 Is Unique
# Similar: 217. [Contains Duplicate](https://leetcode.com/problems/contains-duplicate/) **Easy**
#
# 1.2 Check Permutation
# Same: 242. [Valid Anagram](https://leetcode.com/problems/valid-anagram/) **Easy**
# Hard: 567. [Permutation in String](https://leetcode.com/problems/permutation-in-string/) **Medium**
#
# 1.3 URLify ← Not Found
#
# 1.4 Palindrome Permutation
# Same: 266. [Palindrome Permutation](https://leetcode.com/problems/palindrome-permutation/) **Easy**
#
# 1.5 One Away
# Same: 161. [One Edit Distance](https://leetcode.com/problems/one-edit-distance/) **Medium**
# Hard: 72. [Edit Distance](https://leetcode.com/problems/edit-distance/) **Hard**
#
# 1.6 String Compression
# Same: 443. [String Compression](https://leetcode.com/problems/string-compression/) **Medium**
#
# 1.7 Rotate Matrix
# Same: 48. [Rotate Image](https://leetcode.com/problems/rotate-image/)**Medium**
#
# 1.8 Zero Matrix
# Same: 73. [Set Matrix Zeroes](https://leetcode.com/problems/set-matrix-zeroes/) **Medium**
#
# 1.9 String Rotation
# Same: 796. [Rotate String](https://leetcode.com/problems/rotate-string/)**Easy**

# %% [markdown]
# ## (4.a) Solving only easy questions

# %% [markdown]
# **1.1 Is Unique** Implement an algorithm to determine if a string has all Unique Characters. what if you cannot use any additional data structures?

# %% [markdown]
# **(1)** Python can have else even for "for" loop https://www.geeksforgeeks.org/using-else-conditional-statement-with-for-loop-in-python/
# **(2)** Break Continue and return in python https://www.learnpython.dev/02-introduction-to-python/110-control-statements-looping/50-exercise/

# %%
# %%time
def is_unique(string):
    alpha = 'abcdefghijklmnopqrstuvwxyz'
    alphalen = len(alpha)
    unique_bool = True
    for i in string:
        alpha = alpha.replace(i,'')
        if alphalen == len(alpha):
            unique_bool = False
            break
        else:
            alphalen = len(alpha)
    
    if unique_bool:
        value =  'No duplicate characters'
    else:
        value = 'Has duplicate characters'
    return print(value)
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 8.11 µs

# %%
is_unique('apple')
# Out:
# Has duplicate characters

# %%
is_unique('aple')
# Out:
# No duplicate characters
